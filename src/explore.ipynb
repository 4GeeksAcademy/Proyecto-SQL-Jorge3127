# %% [markdown]
# # Explore here
#
# It's recommended to use this notebook for exploration purposes.
#
# For example:
#
# 1. You could import the CSV generated by python into your notebook and explore it.
# 2. You could connect to your database using `pandas.read_sql` from this notebook and explore it.

# %%
# Example reading the SQL database from here
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pandas as pd

# load the .env file variables
load_dotenv()

connection_string = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}/{os.getenv('DB_NAME')}"
engine = create_engine(connection_string).execution_options(autocommit=True)
engine.connect()

# dataframe = pd.read_sql("Select * from books;", engine)
# print(dataframe.describe())

# %%
import os
from sqlalchemy import create_engine, text
import pandas as pd
from dotenv import load_dotenv

# Cargar variables de entorno
load_dotenv()

# Parámetros de conexión
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")

# Crear motor de conexión
engine = create_engine(f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")

# Probar la conexión y listar tablas
try:
    with engine.connect() as connection:
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema='public'"))
        tables = result.fetchall()
        print("Tablas disponibles:", [table[0] for table in tables])
except Exception as e:
    print(f"Error al conectar a la base de datos: {e}")

# Consultar y mostrar datos de una tabla específica
def fetch_table_data(table_name: str):
    try:
        query = f"SELECT * FROM {table_name} LIMIT 10"
        df = pd.read_sql(query, engine)
        print(f"Datos de la tabla '{table_name}':")
        display(df)
    except Exception as e:
        print(f"Error al consultar la tabla {table_name}: {e}")

# Ejecución de ejemplo
if __name__ == "__main__":
    # Reemplazar con una tabla existente en tu base de datos
    fetch_table_data("your_table_name")
# Out:
# Error al conectar a la base de datos: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 3306 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 3306 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error al consultar la tabla your_table_name: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 3306 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 3306 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# Cargar las variables de entorno
load_dotenv()

# Crear la URL de conexión a la base de datos
DATABASE_URL = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/{os.getenv('DB_NAME')}"

# Conectar a la base de datos
try:
    engine = create_engine(DATABASE_URL)
    with engine.connect() as connection:
        print("Conexión exitosa a la base de datos")

        # Consultar las tablas disponibles
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"))
        tables = [row[0] for row in result]
        print("Tablas disponibles en la base de datos:", tables)

        # Consultar datos de cada tabla y mostrarlos con pandas
        for table in tables:
            query = text(f"SELECT * FROM {table} LIMIT 5")
            df = pd.read_sql(query, connection)
            print(f"\nDatos de la tabla '{table}':")
            print(df)

except Exception as e:
    print(f"Error al conectar o consultar la base de datos: {e}")
# Out:
# Error al conectar o consultar la base de datos: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 3306 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 3306 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# Cargar las variables de entorno
load_dotenv()

# Crear la URL de conexión a la base de datos
DATABASE_URL = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:5432/{os.getenv('DB_NAME')}"

# Conectar a la base de datos
try:
    engine = create_engine(DATABASE_URL)
    with engine.connect() as connection:
        print("Conexión exitosa a la base de datos")

        # Consultar las tablas disponibles
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"))
        tables = [row[0] for row in result]
        print("Tablas disponibles en la base de datos:", tables)

        # Consultar datos de cada tabla y mostrarlos con pandas
        for table in tables:
            query = text(f"SELECT * FROM {table} LIMIT 5")
            df = pd.read_sql(query, connection)
            print(f"\nDatos de la tabla '{table}':")
            print(df)

except Exception as e:
    print(f"Error al conectar o consultar la base de datos: {e}")
# Out:
# Error al conectar o consultar la base de datos: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  role "gitpod" does not exist
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# Cargar las variables de entorno
load_dotenv()

# Crear la URL de conexión a la base de datos
DATABASE_URL = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:5432/{os.getenv('DB_NAME')}"

# Conectar a la base de datos
try:
    engine = create_engine(DATABASE_URL)
    with engine.connect() as connection:
        print("Conexión exitosa a la base de datos")

        # Consultar las tablas disponibles
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"))
        tables = [row[0] for row in result]
        print("Tablas disponibles en la base de datos:", tables)

        # Consultar datos de cada tabla y mostrarlos con pandas
        for table in tables:
            query = text(f"SELECT * FROM {table} LIMIT 5")
            df = pd.read_sql(query, connection)
            print(f"\nDatos de la tabla '{table}':")
            print(df)

except Exception as e:
    print(f"Error al conectar o consultar la base de datos: {e}")

# Verificar conexión manualmente
if __name__ == "__main__":
    try:
        with engine.connect() as conn:
            conn.execute(text("SELECT 1"))
            print("Conexión verificada correctamente.")
    except Exception as conn_error:
        print(f"Error al verificar la conexión: {conn_error}")")
    }
  ]
}
# Out:
#   Cell In[5], line 40
#     print(f"Error al verificar la conexión: {conn_error}")")
#                                                           ^
# SyntaxError: unterminated string literal (detected at line 40)

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# Cargar las variables de entorno
load_dotenv()

# Crear la URL de conexión a la base de datos
DATABASE_URL = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:5432/{os.getenv('DB_NAME')}"

# Conectar a la base de datos
try:
    engine = create_engine(DATABASE_URL)
    with engine.connect() as connection:
        print("Conexión exitosa a la base de datos")

        # Consultar las tablas disponibles
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"))
        tables = [row[0] for row in result]
        print("Tablas disponibles en la base de datos:", tables)

        # Consultar datos de cada tabla y mostrarlos con pandas
        for table in tables:
            query = text(f"SELECT * FROM {table} LIMIT 5")
            df = pd.read_sql(query, connection)
            print(f"\nDatos de la tabla '{table}':")
            print(df)

except Exception as e:
    print(f"Error al conectar o consultar la base de datos: {e}")

# Verificar conexión manualmente
if __name__ == "__main__":
    try:
        with engine.connect() as conn:
            conn.execute(text("SELECT 1"))
            print("Conexión verificada correctamente.")
    except Exception as conn_error:
        print(f"Error al verificar la conexión: {conn_error}")
    }
  ]
}
# Out:
#   File <string>:42
#     ]
#      ^
# IndentationError: unindent does not match any outer indentation level

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# Cargar las variables de entorno
load_dotenv()

# Crear la URL de conexión a la base de datos
DATABASE_URL = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:5432/{os.getenv('DB_NAME')}"

# Conectar a la base de datos
try:
    engine = create_engine(DATABASE_URL)
    with engine.connect() as connection:
        print("Conexión exitosa a la base de datos")

        # Consultar las tablas disponibles
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"))
        tables = [row[0] for row in result]
        print("Tablas disponibles en la base de datos:", tables)

        # Consultar datos de cada tabla y mostrarlos con pandas
        for table in tables:
            query = text(f"SELECT * FROM {table} LIMIT 5")
            df = pd.read_sql(query, connection)
            print(f"\nDatos de la tabla '{table}':")
            print(df)

except Exception as e:
    print(f"Error al conectar o consultar la base de datos: {e}")

# Verificar conexión manualmente
if __name__ == "__main__":
    try:
        with engine.connect() as conn:
            conn.execute(text("SELECT 1"))
            print("Conexión verificada correctamente.")
    except Exception as conn_error:
        print(f"Error al verificar la conexión: {conn_error}")
# Out:
# Error al conectar o consultar la base de datos: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  role "gitpod" does not exist
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error al verificar la conexión: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  role "gitpod" does not exist
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# Cargar las variables de entorno
load_dotenv()

# Depuración: Imprimir variables cargadas
print("DB_USER:", os.getenv('DB_USER'))
print("DB_HOST:", os.getenv('DB_HOST'))
print("DB_NAME:", os.getenv('DB_NAME'))

# Crear la URL de conexión a la base de datos
DATABASE_URL = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:5432/{os.getenv('DB_NAME')}"

# Conectar a la base de datos
try:
    engine = create_engine(DATABASE_URL)
    with engine.connect() as connection:
        print("Conexión exitosa a la base de datos")

        # Consultar las tablas disponibles
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"))
        tables = [row[0] for row in result]
        print("Tablas disponibles en la base de datos:", tables)

        # Consultar datos de cada tabla y mostrarlos con pandas
        for table in tables:
            query = text(f"SELECT * FROM {table} LIMIT 5")
            df = pd.read_sql(query, connection)
            print(f"\nDatos de la tabla '{table}':")
            print(df)

except Exception as e:
    print(f"Error al conectar o consultar la base de datos: {e}")

# Verificar conexión manualmente
if __name__ == "__main__":
    try:
        with engine.connect() as conn:
            conn.execute(text("SELECT 1"))
            print("Conexión verificada correctamente.")
    except Exception as conn_error:
        print(f"Error al verificar la conexión: {conn_error}")
# Out:
# DB_USER: gitpod
# DB_HOST: localhost
# DB_NAME: sample_db
# Error al conectar o consultar la base de datos: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  role "gitpod" does not exist
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error al verificar la conexión: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  role "gitpod" does not exist
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# Cargar las variables de entorno
load_dotenv()

# Depuración: Imprimir variables cargadas
print("DB_USER:", os.getenv('DB_USER'))
print("DB_HOST:", os.getenv('DB_HOST'))
print("DB_NAME:", os.getenv('DB_NAME'))

# Verificar y corregir si el usuario es 'gitpod'
if os.getenv('DB_USER') == 'gitpod':
    print("Detectado usuario 'gitpod', cambiando a 'Jorge3127'")
    os.environ['DB_USER'] = 'Jorge3127'

# Crear la URL de conexión a la base de datos
DATABASE_URL = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:5432/{os.getenv('DB_NAME')}"

# Conectar a la base de datos
try:
    engine = create_engine(DATABASE_URL)
    with engine.connect() as connection:
        print("Conexión exitosa a la base de datos")

        # Consultar las tablas disponibles
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"))
        tables = [row[0] for row in result]
        print("Tablas disponibles en la base de datos:", tables)

        # Consultar datos de cada tabla y mostrarlos con pandas
        for table in tables:
            query = text(f"SELECT * FROM {table} LIMIT 5")
            df = pd.read_sql(query, connection)
            print(f"\nDatos de la tabla '{table}':")
            print(df)

except Exception as e:
    print(f"Error al conectar o consultar la base de datos: {e}")

# Verificar conexión manualmente
if __name__ == "__main__":
    try:
        with engine.connect() as conn:
            conn.execute(text("SELECT 1"))
            print("Conexión verificada correctamente.")
    except Exception as conn_error:
        print(f"Error al verificar la conexión: {conn_error}")
# Out:
# DB_USER: gitpod
# DB_HOST: localhost
# DB_NAME: sample_db
# Detectado usuario 'gitpod', cambiando a 'Jorge3127'
# Error al conectar o consultar la base de datos: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  role "Jorge3127" does not exist
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error al verificar la conexión: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  role "Jorge3127" does not exist
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# Cargar las variables de entorno
load_dotenv()

# Depuración: Imprimir variables cargadas
print("DB_USER:", os.getenv('DB_USER'))
print("DB_HOST:", os.getenv('DB_HOST'))
print("DB_NAME:", os.getenv('DB_NAME'))

# Verificar y corregir si el usuario es 'gitpod'
if os.getenv('DB_USER') == 'gitpod':
    print("Detectado usuario 'gitpod', cambiando a 'Jorge3127'")
    os.environ['DB_USER'] = 'Jorge3127'

# Crear la URL de conexión a la base de datos
DATABASE_URL = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:5432/{os.getenv('DB_NAME')}"

# Conectar a la base de datos
try:
    engine = create_engine(DATABASE_URL)
    with engine.connect() as connection:
        print("Conexión exitosa a la base de datos")

        # Consultar las tablas disponibles
        result = connection.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"))
        tables = [row[0] for row in result]
        print("Tablas disponibles en la base de datos:", tables)

        # Consultar datos de cada tabla y mostrarlos con pandas
        for table in tables:
            query = text(f"SELECT * FROM {table} LIMIT 5")
            df = pd.read_sql(query, connection)
            print(f"\nDatos de la tabla '{table}':")
            print(df)

except Exception as e:
    print(f"Error al conectar o consultar la base de datos: {e}")

# Verificar conexión manualmente
if __name__ == "__main__":
    try:
        with engine.connect() as conn:
            conn.execute(text("SELECT 1"))
            print("Conexión verificada correctamente.")
    except Exception as conn_error:
        print(f"Error al verificar la conexión: {conn_error}")
# Out:
# DB_USER: Jorge3127
# DB_HOST: localhost
# DB_NAME: sample_db
# Conexión exitosa a la base de datos
# Tablas disponibles en la base de datos: []
# Conexión verificada correctamente.
